# %%
import pandas as pd

UCLA_CSV_PATH = '/radraid2/dongwoolee/VNet_LungNoduleSeg/richard/data/UCLAIDx_Task78_Lesion_info.csv'
NLST_CSV_PATH = '/radraid2/dongwoolee/VNet_LungNoduleSeg/richard/data/NLST_merged_lesion_info.csv'
LIDC_CSV_PATH = '/radraid2/dongwoolee/VNet_LungNoduleSeg/richard/data/LIDC_lesion_info_maybe.csv'

NODULE_LIST_PATH = '/radraid2/dongwoolee/VNet_LungNoduleSeg/richard/data/images_and_segpaths_2024-12-11-checkpoint.csv'

ucla_csv = pd.read_csv(UCLA_CSV_PATH, index_col=0)
nlst_csv = pd.read_csv(NLST_CSV_PATH)
lidc_csv = pd.read_csv(LIDC_CSV_PATH, index_col=0)

nodule_list = pd.read_csv(NODULE_LIST_PATH)

ucla_features = ["patient_id", "nodule_id", "dr_diaag_code", "nodule_category", "consistency", 
                 "location", "margins", "suspicion", "diam_long", "diam_small"]
nlst_features = ["pid", "nodule_id", "level_of_suspicion_of_lung_cancer", 
                 "slice_thickness", "kernel", "scanner_manufacturer", "scanner_model",  "axial_location",
                 "longest_axial_diameter_(mm)", "short_diameter_(mm)", "nodule_margin_conspicuity", "nodule_margins",
                 "additional_nodule_margins", "nodule_shape", "nodule_consistency", "cyst-like_spaces",
                 "pleural_attachment", "pleural_retraction", "vascular_convergence", "septal_stretching",
                 "paracicatricial_emphysema", "predominant_nature_of_lung_parenchyma", "fibrosis",
                 "fibrosis_distribution"]
lidc_features = ["pid", "nodule_id", "sphericity", "lobulation", "texture", "margin", "spiculation", "malignancy",
                 "diameter", "internalStructure", "calcification"]
nodule_list_features = ["pid", "texture", "scanner", "study_desc"]

# %%
def combine_dice_score(original_df, dice_df, filename_col, map_dict):
    """
    Combines the dice score from dice_df into original_df using a mapping.

    Args:
        original_df (pd.DataFrame): The main DataFrame, must contain a 'pid' column.
        dice_df (pd.DataFrame): DataFrame with dice scores, must contain 'filename_col' and 'dice_score'.
        filename_col (str): The name of the column in dice_df that contains the filenames (the keys of map_dict).
        map_dict (dict): A dictionary mapping values from dice_df[filename_col] to 'pid' values in original_df.
                          Example: {'dice_df_filename_value': 'original_df_pid_value'}
    """
    # Make copies of the dataframes to avoid modifying the original ones
    original_df_copy = original_df.copy()
    dice_df_copy = dice_df.copy()

    # Map the filename to the pid
    dice_df_copy['pid'] = dice_df_copy[filename_col].map(map_dict)
    missing_maps = dice_df_copy['pid'].isnull().sum()

    # Check if any filenames could not be mapped
    if missing_maps > 0:
        print(f"Warning: {missing_maps} filenames in '{filename_col}' column of dice_df could not be mapped to a 'pid' using map_dict.")

    # Merge the dice score into the original dataframe
    dice_df_to_merge = dice_df_copy[['pid', 'dice_score']]
    merged_df = original_df_copy.merge(dice_df_to_merge, on='pid', how='left')

    return merged_df

# %% [markdown]
# ## Value Counts

# %% [markdown]
# ### UCLA

# %%
### UCLA
ucla_value_counts = {}
for feature in ucla_features:
    if feature not in ["patient_id", "nodule_id", "diam_long", "diam_small"]:
        ucla_value_counts[feature] = ucla_csv[feature].value_counts(dropna=False)
        print(ucla_value_counts[feature])
        print()

### NLST
nlst_value_counts = {}
for feature in nlst_features:
    if feature not in ["pid", "nodule_id", "longest_axial_diameter_(mm)", "short_diameter_(mm)"]:
        nlst_value_counts[feature] = nlst_csv[feature].value_counts(dropna=False)
        print(nlst_value_counts[feature])
        print()

### LIDC
lidc_value_counts = {}
for feature in lidc_features:
    if feature not in ["pid", "nodule_id", "diameter"]:
        lidc_value_counts[feature] = lidc_csv[feature].value_counts(dropna=False)
        print(lidc_value_counts[feature])
        print()

### Nodule List
nodule_list_value_counts = {}
for feature in nodule_list_features:
    if feature not in ["pid"]:
        nodule_list_value_counts[feature] = nodule_list[feature].value_counts(dropna=False)
        print(nodule_list_value_counts[feature])
        print()
# Out:
# dr_diaag_code
# Lung Procedure - Core Needle Biopsy    662
# Lung Diagnostic Imaging                394
# Lung Screening LDCT                     38
# Lung Non-Screening LDCT                 34
# Lung Pathology - Biopsy                 15
# NaN                                      5
# Name: count, dtype: int64
#
# nodule_category
# Principal Nodule        1007
# NaN                       59
# Category 3-4x Nodule      45
# Other Nodule              31
# Category 2 Nodule          6
# Name: count, dtype: int64
#
# consistency
# Solid              738
# PSN                179
# Unknown            101
# Pure GGN            83
# Cavitary            23
# Cyst-associated     10
# NaN                 10
# Not specified        4
# Name: count, dtype: int64
#
# location
# RUL = Right Upper Lobe     294
# RLL = Right Lower Lobe     269
# LUL = Left Upper Lobe      237
# LLL = Left Lower Lobe      215
# RML = Right Middle Lobe     92
# Lingula                     20
# NaN                          9
# Other                        7
# Mediastinum                  3
# Right Hilum                  2
# Name: count, dtype: int64
#
# margins
# NaN                    508
# Smooth                 232
# Spiculated/Serrated    189
# Poorly marginated      130
# Lobulated               62
# Other                   27
# Name: count, dtype: int64
#
# suspicion
# NaN                489
# Low                382
# Not Specified      244
# Moderately High     15
# High                15
# Intermediate         2
# Moderately Low       1
# Name: count, dtype: int64
#
# level_of_suspicion_of_lung_cancer
# NaN                2039
# Intermediate       1481
# Moderately Low      829
# Very Low            702
# Moderately High     510
# High                354
# Name: count, dtype: int64
#
# slice_thickness
# NaN       4654
# 2.5 mm     577
# 2 mm       507
# 1 mm       105
# >3 mm       57
# 1.5 mm      15
# Name: count, dtype: int64
#
# kernel
# NaN       4670
# Medium    1204
# Sharp       41
# Name: count, dtype: int64
#
# scanner_manufacturer
# NaN        4654
# GE          675
# Siemens     430
# Toshiba      81
# Philips      75
# Name: count, dtype: int64
#
# scanner_model
# NaN                4657
# VZOOM               204
# LSQX                188
# LS16                152
# SEN16               114
# LSULT                91
# AQUL4                79
# MX8000               72
# HSQX                 72
# LSPR16               66
# LSPLUS               65
# SEN64                38
# Sensation 16         38
# SEN4                 13
# DSCLS                 9
# LS 16                 8
# SEN14                 7
# LSPR 16               5
# ZVOOM                 4
# LightSpeed Plus       3
# LSPR                  3
# Sens 16               2
# Sen 16                2
# UNK                   2
# Sensation 4           2
# LSPR 1.25             2
# Sensation 64          2
# Aqul4                 1
# Aqul 4                1
# Aquillon              1
# lsqx                  1
# GE LS16               1
# Aqul 4                1
# Lightspeed 16         1
# LSQX 1.25             1
# Sen4                  1
# SEN 16                1
# LSPWR                 1
# LS 16 1.25            1
# Lightspeed QX         1
# Senation 4            1
# Aqui                  1
# Name: count, dtype: int64
#
# axial_location
# NaN           4658
# Peripheral     730
# Central        527
# Name: count, dtype: int64
#
# nodule_margin_conspicuity
# Well marginated      3242
# NaN                  2043
# Poorly marginated     630
# Name: count, dtype: int64
#
# nodule_margins
# NaN                    4353
# Smooth                  716
# Lobulated               454
# Ill-defined             202
# Spiculated/Serrated     187
# Notched (concavity)       3
# Name: count, dtype: int64
#
# additional_nodule_margins
# NaN                    4418
# Smooth                  612
# Spiculated              260
# Lobulated               203
# Ill-defined             202
# Spiculated/Serrated     199
# Notched (concavity)      21
# Name: count, dtype: int64
#
# nodule_shape
# NaN                  2040
# Round                2017
# Ovoid                1244
# Complex/Irregular     471
# Polygonal             143
# Name: count, dtype: int64
#
# nodule_consistency
# Solid                2839
# NaN                  2030
# Part-solid            582
# Pure ground glass     339
# Semiconsolidation     101
# Peri-cystic            24
# Name: count, dtype: int64
#
# cyst-like_spaces
# NaN        4661
# Absent     1080
# Present     174
# Name: count, dtype: int64
#
# pleural_attachment
# NaN        4658
# Present     649
# Absent      608
# Name: count, dtype: int64
#
# pleural_retraction
# NaN                 4657
# Absent               985
# Mild dimpling        211
# Obvious dimpling      62
# Name: count, dtype: int64
#
# vascular_convergence
# NaN        4659
# Absent     1094
# Present     162
# Name: count, dtype: int64
#
# septal_stretching
# NaN        4657
# Absent      849
# Present     409
# Name: count, dtype: int64
#
# paracicatricial_emphysema
# NaN        4659
# Absent     1116
# Present     140
# Name: count, dtype: int64
#
# predominant_nature_of_lung_parenchyma
# NaN            4657
# Normal lung     966
# Emphysema       278
# Fibrosis         14
# Name: count, dtype: int64
#
# fibrosis
# NaN        4659
# Absent      739
# Present     517
# Name: count, dtype: int64
#
# fibrosis_distribution
# NaN        5393
# Focal       498
# Diffuse      24
# Name: count, dtype: int64
#
# sphericity
# 4.0    803
# 3.0    633
# 5.0    444
# 3.5    276
# 4.5    261
# 2.0    132
# 2.5     76
# 1.5      3
# 1.0      2
# Name: count, dtype: int64
#
# lobulation
# 1.0    1554
# 2.0     393
# 1.5     268
# 3.0     170
# 2.5     103
# 4.0      59
# 3.5      36
# 5.0      34
# 4.5      13
# Name: count, dtype: int64
#
# texture
# 5.0    1814
# 1.0     204
# 4.0     204
# 4.5     147
# 3.0     122
# 2.0      57
# 3.5      54
# 1.5      16
# 2.5      12
# Name: count, dtype: int64
#
# margin
# 5.0    858
# 4.0    655
# 3.0    283
# 4.5    280
# 2.0    194
# 3.5    152
# 1.0    118
# 2.5     60
# 1.5     30
# Name: count, dtype: int64
#
# spiculation
# 1.0    1757
# 2.0     291
# 1.5     257
# 3.0     111
# 2.5      63
# 4.0      59
# 5.0      43
# 3.5      28
# 4.5      21
# Name: count, dtype: int64
#
# malignancy
# 3.0    953
# 2.0    510
# 1.0    324
# 2.5    272
# 4.0    187
# 3.5    163
# 5.0    115
# 4.5     70
# 1.5     36
# Name: count, dtype: int64
#
# internalStructure
# 1        2614
# [1 4]       6
# 4           4
# 2           3
# [1 2]       2
# 5           1
# Name: count, dtype: int64
#
# calcification
# 6            2308
# 3             255
# [3 6]          25
# 5               8
# [4 6]           8
# [5 6]           8
# 4               4
# [3 5]           3
# [3 4 5 6]       2
# [2 3]           2
# [3 5 6]         2
# [2 6]           1
# [1 2 4 6]       1
# [3 4]           1
# [1 5]           1
# [4 5]           1
# Name: count, dtype: int64
#
# texture
# Solid                4005
# Solid/Mixed           445
# Non-Solid/GGO         268
# Part Solid/Mixed      214
# PSN                   157
# Part-solid            133
# Pure ground glass     119
# Semiconsolidation     101
# Unknown                93
# Non-Solid/Mixed        84
# Pure GGN               79
# Peri-cystic            24
# Cavitary               19
# Cyst-associated        10
# Not specified           4
# Name: count, dtype: int64
#
# scanner
# GE MEDICAL SYSTEMS             2166
# NaN                            1090
# SIEMENS                         696
# GE                              674
# Siemens                         430
# Philips                         353
# TOSHIBA                         199
# Toshiba                          81
# Philips Medical Systems          27
# GE Healthcare""                  15
# KODAK                            11
# DeJarnette Research Systems      10
# FUJI PHOTO FILM Co., ltd.         3
# Name: count, dtype: int64
#
# study_desc
# NaN                       4341
# CHEST, PA & LATERAL        273
# CHEST                      189
# CT LUNG SCREEN             185
# CT THORAX W/CONTRAST       161
# CT CHEST O CONTR           104
# CT CHEST WO CONTRAST        64
# CT GUIDED LUNG B            58
# CHEST 2 VIEW                52
# CT THORAX WO IV CONTRA      40
# CT ANGIO CHEST W&W/O C      39
# CHEST PA - LAT              31
# CT ANGIO CHEST (NON-CO      29
# CT GUIDED LUNG BIOPSY       22
# CT THORAX W/O CONTRAST      19
# CAP                         19
# CT CHEST W/ CONT            18
# CHEST/ABD/PELVIS            11
# PE CHEST WITH               11
# CT CHEST W/O CON            10
# CT CAP                       9
# POST CHEST                   8
# CT-CH/A/P LIVER              6
# CT, LUNG, MED, PLEURA        5
# CT THORAX W IV CONTRAS       5
# CT CHEST  NO IV              3
# CT CH/AB/PEL W/O             3
# CT CHE/ABD/PEL               3
# CT C/A                       3
# CT CAP W                     3
# CT/C-A-P                     2
# CH/ABD/PELVIS                2
# CAP LYM PRE/POST             2
# CT CHEST PE                  2
# CT CH/ABD/PELVIS             2
# CHEST PA AND LATERAL         2
# CAP W/CON                    2
# CT CHE./ABD/PEL-LIVER        2
# CT  C/A/P  W/O CONT          2
# CT-CH/A/P                    2
# T/A/P W/C                    1
# THORAX WITH                  1
# PRE CHEST                    1
# CT C/A/P                     1
# CT CH/AB/PELVIS              1
# CH-AB W/WO                   1
# CHEST/ABD W/C                1
# CT CAP W/CONTRAST            1
# C/A/P POST                   1
# C-A-P                        1
# CT CHEST                     1
# Name: count, dtype: int64
